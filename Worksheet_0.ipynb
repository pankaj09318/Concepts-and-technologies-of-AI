# %% [markdown]
# <a href="https://colab.research.google.com/github/pankaj09318/Concepts-and-technologies-of-AI/blob/main/Worksheet_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#task 1,2,3
time_data = [
(3.5, 2.0, 7.0), (5.0, 1.5, 6.5), (2.5, 3.0, 8.0),
(4.0, 2.0, 6.0), (1.5, 4.5, 9.0), (3.0, 2.5, 7.5),
(5.5, 1.0, 6.0), (2.0, 3.5, 8.5), (4.5, 2.0, 7.0),
(3.0, 3.0, 7.5), (6.0, 1.5, 6.0), (2.5, 4.0, 8.0),
(4.0, 2.5, 7.0), (5.0, 2.0, 6.5), (3.5, 2.5, 7.0)
]

study_hours = [data[0] for data in time_data]

low = []
moderate = []
high = []

for h in study_hours:
    if h < 3:
        low.append(h)
    elif h > 5:
        high.append(h)
    else:
        moderate.append(h)

print("Low study hours:", low)
print("Moderate study hours:", moderate)
print("High study hours:", high)

low_study_time = len(low)
moderate_study_time = len(moderate)
high_study_time = len(high)

print("Count of low study hours:", low_study_time)
print("Count of moderate study hours:", moderate_study_time)
print("Count of high study hours:", high_study_time)

study_minutes =[]

for h in study_hours:
  minutes = h*60
  study_minutes.append(minutes)
print("study hours in minutes: ",study_minutes)
# Out:
# Low study hours: [2.5, 1.5, 2.0, 2.5]
# Moderate study hours: [3.5, 5.0, 4.0, 3.0, 4.5, 3.0, 4.0, 5.0, 3.5]
# High study hours: [5.5, 6.0]
# Count of low study hours: 4
# Count of moderate study hours: 9
# Count of high study hours: 2
# study hours in minutes:  [210.0, 300.0, 150.0, 240.0, 90.0, 180.0, 330.0, 120.0, 270.0, 180.0, 360.0, 150.0, 240.0, 300.0, 210.0]

# %%
#task 4,5
# Daily time (in hours): [study, entertainment, sleep]
import matplotlib.pyplot as plt
time_data = [
(3.5, 2.0, 7.0), (5.0, 1.5, 6.5), (2.5, 3.0, 8.0),
(4.0, 2.0, 6.0), (1.5, 4.5, 9.0), (3.0, 2.5, 7.5),
(5.5, 1.0, 6.0), (2.0, 3.5, 8.5), (4.5, 2.0, 7.0),
(3.0, 3.0, 7.5), (6.0, 1.5, 6.0), (2.5, 4.0, 8.0),
(4.0, 2.5, 7.0), (5.0, 2.0, 6.5), (3.5, 2.5, 7.0)
]
study_hours = [data[0] for data in time_data]
entertainment_hours = [data[1] for data in time_data]
sleep_hours = [data[2] for data in time_data ]

avg_study_hours = sum(study_hours)/len(study_hours)
print("average study hours is ", avg_study_hours)

avg_entertainment_hours = sum(entertainment_hours)/len(entertainment_hours)
print("average entertainment hours is ", avg_entertainment_hours)

avg_sleep_hours = sum(sleep_hours)/len(sleep_hours)
print("average sleep hours is ", avg_sleep_hours)

plt.figure(figsize=(8, 6))
plt.scatter(study_hours, sleep_hours, color='skyblue', alpha=0.7)
plt.title('Study Hours vs. Sleep Hours')
plt.xlabel('Study Hours')
plt.ylabel('Sleep Hours')
plt.grid(True)
plt.show()
# Out:
# average study hours is  3.7
# average entertainment hours is  2.5
# average sleep hours is  7.166666666666667

# %%
#sum of nested list
def sum_nested_list(nested_list):
  total = 0
  for element in nested_list:
    if isinstance(element, list): # Check if the element is a list
      total += sum_nested_list(element) # Recursively sum the nested list
    else:
      total += element # Add the number to the total
  return total
nested_list = [1,  [ 2, [3, 4], 5], 6,[7,8]]
result = sum_nested_list(nested_list)
print("Sum is:",result)
# Out:
# Sum is: 36

# %%
#permutation
def generate_permutations(s):
    if len(s) == 1:
        return [s]
    result = []
    for i in range(len(s)):
        char = s[i]
        for perm in generate_permutations(s[:i] + s[i+1:]):
            result.append(char + perm)
    return list(set(result))
print(generate_permutations("abc"))
print(generate_permutations("aab"))
# Out:
# ['cba', 'abc', 'cab', 'bca', 'acb', 'bac']
# ['aba', 'baa', 'aab']

# %%
#Sample directory structure
directory_structure = {
    "file1.txt": 200,
    "file2.txt": 300,
    "subdir1": {
        "file3.txt": 400,
        "file4.txt": 100
    },
    "subdir2": {
        "subsubdir1": {
            "file5.txt": 250
        },
        "file6.txt": 150
    }
}
def calculate_directory_size(directory):
    total_size = 0

    for key, value in directory.items():
        if isinstance(value, int):
            total_size += value
        elif isinstance(value, dict):
            total_size += calculate_directory_size(value)

    return total_size
Total = calculate_directory_size(directory_structure)
print("Total size of the directory:",Total,"KB")
# Out:
# Total size of the directory: 1400 KB

# %%
def min_coins(coins, amount):
  """
  Finds the minimum number of coins needed to make up a given amount using dynamic
  programming.
  Parameters:
  coins (list of int): A list of coin denominations available for making change.
  Each coin denomination is a positive integer.
  amount (int): The target amount for which we need to find the minimum number of
  coins. It must be a non-negative integer.
  Returns:
  int: The minimum number of coins required to make the given amount.
  If it is not possible to make the amount with the given coins, returns -1
  """
  dp = [float('inf')] * (amount + 1)
  dp[0] = 0
  for coin in coins:
    for i in range(coin, amount + 1):
      dp[i] = min(dp[i], dp[i - coin] + 1)
  return dp[amount] if dp[amount] != float('inf') else -1
coins = [1, 2, 5]
amount = 11
print("Minimum coins needed:",min_coins(coins,amount))
# Out:
# Minimum coins needed: 3

# %%
def longest_common_subsequence(s1, s2):
    n1 = len(s1)
    n2 = len(s2)

    dp = [[0] * (n2 + 1) for _ in range(n1 + 1)]

    for i in range(1, n1 + 1):
        for j in range(1, n2 + 1):
            if s1[i - 1] == s2[j - 1]:
                dp[i][j] = dp[i - 1][j - 1] + 1
            else:
                dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])

    return dp[n1][n2]
s1 = "abcde"
s2 = "ace"
result = longest_common_subsequence(s1, s2)
print(f"LCS length of '{s1}' and '{s2}'is:{result}")
# Out:
# LCS length of 'abcde' and 'ace'is:3

# %%
def knapsack(weights, values, capacity):
    n = len(weights)

    dp = [[0 for _ in range(capacity + 1)] for _ in range(n + 1)]

    for i in range(1, n + 1):
        for w in range(1, capacity + 1):
            if weights[i - 1] <= w:
                include = values[i - 1] + dp[i - 1][w - weights[i - 1]]
                exclude = dp[i - 1][w]
                dp[i][w] = max(include, exclude)
            else:
                dp[i][w] = dp[i - 1][w]

    return dp[n][capacity]


# Test the function
weights = [1, 3, 4, 5]
values = [1, 4, 5, 7]
capacity = 7

result = knapsack(weights, values, capacity)
print("Maximum value achievable:", result)
# Out:
# Maximum value achievable: 9
